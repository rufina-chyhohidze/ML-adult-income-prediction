# %%
"""

Choose appropriate metrics to evaluate model performance.
• Apply sound validation techniques (e.g., cross-validation, train-test split).
• Visualize the results using appropriate plots.
• Interpret the results and discuss the various models’ strengths and weaknesses for your problem.


TO MAKE SURE: DATA LEAKEGE (EXPLANATION ON WHATSSAP), We need to make sure that data preprocessing steps of model training and development are the same we use for production, when input comes in, and containerize deployment, btw we need to check if we split the data correctly, cause we have the train data set and the test set but i don’t think we did a validation set that we are supposed to use for when we do the model evaluation and hyperparameter tuning
"""
